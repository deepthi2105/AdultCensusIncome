# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv("adult.csv")

# %%
data.head(20)
# Out:
#     age         workclass  fnlwgt     education  education.num marital.status  \
# 0    90                 ?   77053       HS-grad              9        Widowed
# 1    82           Private  132870       HS-grad              9        Widowed
# 2    66                 ?  186061  Some-college             10        Widowed
# 3    54           Private  140359       7th-8th              4       Divorced
# 4    41           Private  264663  Some-college             10      Separated
# 5    34           Private  216864       HS-grad              9       Divorced
# 6    38           Private  150601          10th              6      Separated
# 7    74         State-gov   88638     Doctorate             16  Never-married
# 8    68       Federal-gov  422013       HS-grad              9       Divorced
# 9    41           Private   70037  Some-college             10  Never-married
# 10   45           Private  172274     Doctorate             16       Divorced
# ...

# %%
#replacing ? with NaN 
data = data.replace('?', np.nan)

# %%
data.head(20)
# Out:
#     age         workclass  fnlwgt     education  education.num marital.status  \
# 0    90               NaN   77053       HS-grad              9        Widowed
# 1    82           Private  132870       HS-grad              9        Widowed
# 2    66               NaN  186061  Some-college             10        Widowed
# 3    54           Private  140359       7th-8th              4       Divorced
# 4    41           Private  264663  Some-college             10      Separated
# 5    34           Private  216864       HS-grad              9       Divorced
# 6    38           Private  150601          10th              6      Separated
# 7    74         State-gov   88638     Doctorate             16  Never-married
# 8    68       Federal-gov  422013       HS-grad              9       Divorced
# 9    41           Private   70037  Some-college             10  Never-married
# 10   45           Private  172274     Doctorate             16       Divorced
# ...

# %%
data.isnull().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education.num        0
# marital.status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital.gain         0
# capital.loss         0
# hours.per.week       0
# native.country     583
# income               0
# dtype: int64

# %%
data.describe()
# Out:
#                 age        fnlwgt  education.num  capital.gain  capital.loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours.per.week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
#since occupation,workclass and native.country are categorical data we can fill the missing values using mode
data['workclass']=data['workclass'].fillna(data['workclass'].dropna().mode().values[0])
data['occupation']=data['occupation'].fillna(data['occupation'].dropna().mode().values[0])
data['native.country']=data['native.country'].fillna(data['native.country'].dropna().mode().values[0])

# %%
data.head(20)
# Out:
#     age         workclass  fnlwgt     education  education.num marital.status  \
# 0    90           Private   77053       HS-grad              9        Widowed
# 1    82           Private  132870       HS-grad              9        Widowed
# 2    66           Private  186061  Some-college             10        Widowed
# 3    54           Private  140359       7th-8th              4       Divorced
# 4    41           Private  264663  Some-college             10      Separated
# 5    34           Private  216864       HS-grad              9       Divorced
# 6    38           Private  150601          10th              6      Separated
# 7    74         State-gov   88638     Doctorate             16  Never-married
# 8    68       Federal-gov  422013       HS-grad              9       Divorced
# 9    41           Private   70037  Some-college             10  Never-married
# 10   45           Private  172274     Doctorate             16       Divorced
# ...

# %%
data.shape
# Out:
# (32561, 15)

# %%
#analysing the data via boxplot
sns.boxplot(data=data,width=0.5,fliersize=5)

# %% [markdown]
# # Visualising the data

# %%
data.boxplot(column='hours.per.week', by='income')

# %% [markdown]
# The boxplot shows a clear variation for different income levels which makes it an important variable for predicting the outcome.

# %%
#number of years of education vs salary
data.boxplot(column='education.num', by='income')

# %% [markdown]
# If years of education varies between 8-11yrs, then income <=50k.
#
# If years of education varies between 6-16yrs, then income >50k

# %%
#agevssalary
data.boxplot(column='age', by='income')

# %% [markdown]
# People between the age of 25 to 45 are more likely to have a salary <=50k

# %%
sns.countplot(y='workclass',hue='income',data=data)

# %% [markdown]
# People from a private class are more likely to have an income <=50k

# %%
sns.countplot(y='education',hue='income',data=data)

# %% [markdown]
# It shows that generally bachelors have a salary greater than 50k

# %%
sns.countplot(y='marital.status',hue='income',data=data)

# %% [markdown]
# People who were never married earned an income <=50k.

# %%
sns.countplot(y='occupation',hue='income',data=data)

# %%
sns.countplot(y='relationship',hue='income',data=data)

# %% [markdown]
# This shows that the husband's of the house have the highest possibility of having an income >50k

# %%
plt.subplots(figsize=(15,10))
sns.heatmap(data.corr())

# %%
X=data.drop('income',axis=1)
Y=data['income']
X=pd.get_dummies(X)

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
clf=LogisticRegression()
clf.fit(X_train,Y_train)
pred=clf.predict(X_test)
print(clf.score(X_test,Y_test))
# Out:
# C:\Users\Deepthi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 0.801320436050975

# %%
from sklearn.tree import DecisionTreeClassifier
clf1=DecisionTreeClassifier()
clf1.fit(X_train,Y_train)
pred=clf1.predict(X_test)
print(clf1.score(X_test,Y_test))
# Out:
# 0.8148318747121143

# %%
#RandomForest
from sklearn.ensemble import RandomForestClassifier
clf2=RandomForestClassifier()
clf2.fit(X_train,Y_train)
pred=clf2.predict(X_test)
print(clf2.score(X_test,Y_test))
# Out:
# C:\Users\Deepthi\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0.8513741747274681

# %%
from sklearn.neighbors import KNeighborsClassifier
clf4=KNeighborsClassifier()
clf4.fit(X_train,Y_train)
pred=clf4.predict(X_test)
print(clf4.score(X_test,Y_test))
# Out:
# 0.7779824965453708

# %% [markdown]
# From the above, we can see that Random Forest has the highest accuracy which is 85.13%
